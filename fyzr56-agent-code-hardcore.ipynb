# %% [markdown]
# # Coursework Template

# %% [markdown]
# ## Setup

# %% [markdown]
# **Dependencies and imports**
#
# This can take a minute...

# %%
# !pip install swig
# !pip install rldurham
# Out:
# Requirement already satisfied: swig in /usr/local/lib/python3.12/dist-packages (4.4.1)
# Requirement already satisfied: rldurham in /usr/local/lib/python3.12/dist-packages (0.1.1)
# Requirement already satisfied: IPython in /usr/local/lib/python3.12/dist-packages (from rldurham) (7.34.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from rldurham) (7.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from rldurham) (2.32.4)
# Requirement already satisfied: gymnasium[Box2D,atari,other] in /usr/local/lib/python3.12/dist-packages (from rldurham) (1.2.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from rldurham) (2.10.0+cpu)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rldurham) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from rldurham) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from rldurham) (2.2.2)
# Requirement already satisfied: lightning in /usr/local/lib/python3.12/dist-packages (from rldurham) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (0.11.2)
# Requirement already satisfied: box2d==2.3.10 in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (4.4.1)
# Requirement already satisfied: moviepy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (1.0.3)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (3.10.0)
# Requirement already satisfied: opencv-python>=3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (4.13.0.92)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.12/dist-packages (from gymnasium[Box2D,atari,other]->rldurham) (0.13.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from IPython->rldurham) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from IPython->rldurham) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from IPython->rldurham) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from IPython->rldurham) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from IPython->rldurham) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from IPython->rldurham) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from IPython->rldurham) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from IPython->rldurham) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from IPython->rldurham) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from IPython->rldurham) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->rldurham) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->rldurham) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->rldurham) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->rldurham) (3.0.16)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning->rldurham) (6.0.3)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning->rldurham) (2025.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning->rldurham) (0.15.3)
# Requirement already satisfied: packaging<27.0,>=23.0 in /usr/local/lib/python3.12/dist-packages (from lightning->rldurham) (26.0)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /usr/local/lib/python3.12/dist-packages (from lightning->rldurham) (1.9.0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning->rldurham) (4.67.3)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning->rldurham) (2.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->rldurham) (3.25.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->rldurham) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->rldurham) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->rldurham) (3.1.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->rldurham) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->rldurham) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->rldurham) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->rldurham) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->rldurham) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->rldurham) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->rldurham) (2026.2.25)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning->rldurham) (3.13.3)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->rldurham) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->rldurham) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->rldurham) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->rldurham) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->rldurham) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->rldurham) (6.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->IPython->rldurham) (0.8.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham) (3.3.2)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham) (2.37.3)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham) (0.6.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->IPython->rldurham) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->rldurham) (0.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->rldurham) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->rldurham) (1.3.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->rldurham) (6.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->rldurham) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning->rldurham) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning->rldurham) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning->rldurham) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning->rldurham) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning->rldurham) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning->rldurham) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning->rldurham) (1.23.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->rldurham) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->rldurham) (5.9.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (7.17.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (1.3.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->rldurham) (4.9.4)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (1.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (2.8.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (4.12.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (1.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->rldurham) (1.4.0)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = ""  # disable CUDA (better on Colab/NCC: choose an environment without GPU)
import torch
import rldurham as rld

# %%
import gymnasium as gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Normal
import numpy as np
import collections, random

import os
from google.colab import drive

# %%
class ReplayBuffer:
    def __init__(self, obs_dim, act_dim, size):
        self.s = np.zeros((size, obs_dim), dtype=np.float32)
        self.a = np.zeros((size, act_dim), dtype=np.float32)
        self.r = np.zeros((size, 1), dtype=np.float32)
        self.sp = np.zeros((size, obs_dim), dtype=np.float32)
        self.d = np.zeros((size, 1), dtype=np.float32)
        self.ptr = 0
        self.size = 0
        self.max_size = size

    def put(self, s, a, r, sp, done):
        self.s[self.ptr] = s
        self.a[self.ptr] = a
        self.r[self.ptr] = r
        self.sp[self.ptr] = sp
        self.d[self.ptr] = 0.0 if done else 1.0
        self.ptr = (self.ptr + 1) % self.max_size
        self.size = min(self.size + 1, self.max_size)

    def sample(self, batch_size):
        idx = np.random.randint(0, self.size, size=batch_size)
        return (
            torch.from_numpy(self.s[idx]),
            torch.from_numpy(self.a[idx]),
            torch.from_numpy(self.r[idx]),
            torch.from_numpy(self.sp[idx]),
            torch.from_numpy(self.d[idx]),
        )

# %%
class PolicyNet(nn.Module):
    def __init__(self, learning_rate, act_dim, obs_dim, init_alpha, lr_alpha):
        super(PolicyNet, self).__init__()
        latent_dim = 256

        self.net = nn.Sequential(
            nn.Linear(obs_dim, latent_dim),
            nn.ReLU(),
            nn.Linear(latent_dim, latent_dim),
            nn.ReLU(),
        )

        self.fc_mu = nn.Linear(latent_dim, act_dim)
        self.fc_std = nn.Linear(latent_dim, act_dim)

        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

        self.log_alpha = torch.tensor(np.log(init_alpha))
        self.log_alpha.requires_grad = True
        self.log_alpha_optimizer = optim.Adam([self.log_alpha], lr=lr_alpha)

    def forward(self, x):
        x = self.net(x)
        mu = self.fc_mu(x)
        log_std = self.fc_std(x)
        log_std = torch.clamp(log_std, -20, 2)
        std = torch.exp(log_std)

        dist = Normal(mu, std)
        action = dist.rsample()

        log_prob = dist.log_prob(action).sum(dim=-1, keepdim=True)
        real_action = torch.tanh(action)
        correction = torch.log(1 - real_action.pow(2) + 1e-7).sum(dim=-1, keepdim=True)
        real_log_prob = log_prob - correction

        return real_action, real_log_prob

    def train_net(self, q1, q2, mini_batch, target_entropy):
        s, _, _, _, _ = mini_batch
        a, log_prob = self.forward(s)
        entropy = -self.log_alpha.exp() * log_prob

        q1_val, q2_val = q1(s, a), q2(s, a)
        q1_q2 = torch.cat([q1_val, q2_val], dim=1)
        min_q = torch.min(q1_q2, 1, keepdim=True)[0]

        loss = -min_q - entropy
        self.optimizer.zero_grad()
        loss.mean().backward()
        torch.nn.utils.clip_grad_norm_(self.parameters(), 1.0)
        self.optimizer.step()

        self.log_alpha_optimizer.zero_grad()
        alpha_loss = -(self.log_alpha.exp() * (log_prob + target_entropy).detach()).mean()
        alpha_loss.backward()
        self.log_alpha_optimizer.step()

    def act_deterministic(self, x):
        x = self.net(x)
        mu = self.fc_mu(x)
        return torch.tanh(mu)

# %%
class QNet(nn.Module):  # critics
    def __init__(self, learning_rate, act_dim, obs_dim):
        super(QNet, self).__init__()
        self.fc_s = nn.Linear(obs_dim, 256)
        self.fc_a = nn.Linear(act_dim, 256)
        self.fc_cat = nn.Linear(512, 256)
        self.fc_out = nn.Linear(256, 1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x, a):
        h1 = F.relu(self.fc_s(x))
        h2 = F.relu(self.fc_a(a))
        cat = torch.cat([h1, h2], dim=1)
        q = F.relu(self.fc_cat(cat))
        q = self.fc_out(q)
        return q

    def train_net(self, target, mini_batch):
        s, a, r, s_prime, done = mini_batch
        loss = F.smooth_l1_loss(self.forward(s, a), target)
        self.optimizer.zero_grad()
        loss.mean().backward()
        torch.nn.utils.clip_grad_norm_(self.parameters(), 1.0)
        self.optimizer.step()

    def soft_update(self, net_target, tau):
        for param_target, param in zip(net_target.parameters(), self.parameters()):
            param_target.data.copy_(param_target.data * (1.0 - tau) + param.data * tau)

# %%
class Agent(nn.Module):

    def __init__(self,
                 env,
                 lr_pi = 3e-4,
                 lr_q = 3e-4,
                 lr_alpha = 3e-4, # for automated alpha update


                 init_alpha=0.1,
                 buffer_limit=1_000_000,
                 gamma=0.99,
                 batch_size=128,
                 tau=0.005,  # for target network soft update
                 target_entropy=None,  # for automated alpha update
                 train_steps= 1,
                 ):
        super().__init__()
        self.env = env
        discrete_act, discrete_obs, act_dim, obs_dim = rld.env_info(env, print_out=True)
        self.act_dim = act_dim
        self.obs_dim = obs_dim

       # print(env.action_space)
        #print(env.action_space.low)
       # print(env.action_space.high)
        self.gamma = gamma
        self.batch_size = batch_size
        self.tau = tau
        self.target_entropy = -4.0

        self.train_steps = train_steps
        self.total_steps = 0
        self.start_steps = 10000
        self.update_every = 4
        self.policy_delay = 2
        self.total_updates = 0

        self.obs_mean = np.zeros(obs_dim)
        self.obs_var  = np.ones(obs_dim)
        self.obs_count = 1

        self.memory = ReplayBuffer(obs_dim, act_dim, buffer_limit)
        self.q1 = QNet(lr_q, act_dim, obs_dim)
        self.q2 = QNet(lr_q, act_dim, obs_dim)
        self.q1_target = QNet(lr_q, act_dim, obs_dim)
        self.q2_target = QNet(lr_q, act_dim, obs_dim)
        self.pi = PolicyNet(lr_pi, act_dim, obs_dim, init_alpha=init_alpha, lr_alpha=lr_alpha)

        self.q1_target.load_state_dict(self.q1.state_dict())
        self.q2_target.load_state_dict(self.q2.state_dict())

    '''def action(self, s):
        if self.total_steps < self.start_steps:
            return self.env.action_space.sample()
        with torch.no_grad():
            a, _ = self.pi(torch.from_numpy(s).float())
        return a.numpy()'''


    def action(self, s, evaluate=False):
        if self.total_steps < self.start_steps and not evaluate:
            return self.env.action_space.sample()

        with torch.no_grad():
            x = torch.from_numpy(s).float()
            if evaluate:
                a = self.pi.act_deterministic(x)
            else:
                a, _ = self.pi(x)

        return a.numpy()

    def put(self, s, a, r, s_prime, done):
        self.memory.put(s, a, r , s_prime, done) # 원래는 R / 10.0 이였음

    '''def train(self):
        if self.memory.size > 1000:
            for i in range(self.train_steps):
                mini_batch = self.memory.sample(self.batch_size)
                td_target = self.calc_target(mini_batch) #s_prime을 이용해서 target reward 반환?
                self.q1.train_net(td_target, mini_batch) #받은걸 목표로 loss 최소화 업데이트
                self.q2.train_net(td_target, mini_batch) #받은걸 목표로 loss 최소화 업데이트
                self.pi.train_net(self.q1, self.q2, mini_batch, target_entropy=self.target_entropy)
                #정책을 업댓?

                self.q1.soft_update(self.q1_target, tau=self.tau) # 타겟도 약간 업뎃
                self.q2.soft_update(self.q2_target, tau=self.tau) # 타겟도 약간 업뎃'''

    def _normalize_obs_batch(self, obs_tensor):
        mean = torch.from_numpy(self.obs_mean).float()
        std = torch.from_numpy(np.sqrt(self.obs_var / self.obs_count + 1e-8)).float()
        return (obs_tensor - mean) / std

    def train(self):
        if self.memory.size > 5000:
            for _ in range(self.train_steps):
                s, a, r, sp, d = self.memory.sample(self.batch_size)
                # 샘플링 후 현재 stats로 일관되게 정규화
                s  = self._normalize_obs_batch(s)
                sp = self._normalize_obs_batch(sp)
                mini_batch = (s, a, r, sp, d)

                td_target = self.calc_target(mini_batch)

                self.q1.train_net(td_target, mini_batch)
                self.q2.train_net(td_target, mini_batch)

                self.total_updates += 1

                if self.total_updates % self.policy_delay == 0:
                    self.pi.train_net(self.q1, self.q2, mini_batch, target_entropy=self.target_entropy)
                    self.q1.soft_update(self.q1_target, tau=self.tau)
                    self.q2.soft_update(self.q2_target, tau=self.tau)

    def calc_target(self, mini_batch):
        s, a, r, s_prime, done = mini_batch

        with torch.no_grad():
            a_prime, log_prob = self.pi(s_prime)
            entropy = -self.pi.log_alpha.exp() * log_prob
            q1_val = self.q1_target(s_prime, a_prime)
            q2_val = self.q2_target(s_prime, a_prime)
            q1_q2 = torch.cat([q1_val, q2_val], dim=1)
            min_q = torch.min(q1_q2, 1, keepdim=True)[0]
            target = r + self.gamma * done * (min_q + entropy)

        return target

    def episode(self):
        done = False
        s, _ = self.env.reset()
        info = {}
        episode_reward = 0.0
        while not done:
            self._update_obs_stats(s)
            s_norm = self._normalize_obs(s)
            a = self.action(s_norm)
            s_prime, r, terminated, truncated, info = self.env.step(a)
            done = terminated or truncated
            episode_reward += r
            self.put(s, a, r, s_prime, terminated)  # raw obs 저장
            s = s_prime

            self.total_steps += 1
            if self.total_steps % self.update_every == 0:
                self.train()
        info['r'] = episode_reward
        return info

    def _update_obs_stats(self, obs):
        self.obs_count += 1
        delta = obs - self.obs_mean
        self.obs_mean += delta / self.obs_count
        delta2 = obs - self.obs_mean          # 새 mean 기준 delta
        self.obs_var  += delta * delta2

    def _normalize_obs(self, obs):
        std = np.sqrt(self.obs_var / self.obs_count + 1e-8)
        return (obs - self.obs_mean) / std

# %%
drive.mount('/content/drive')

os.makedirs('/content/drive/MyDrive/RL_project_hardcore', exist_ok=True)

SAVE_PATH = '/content/drive/MyDrive/RL_project_hardcore/sac_checkpoint.pt'

def save_checkpoint(agent, n_epi, best_reward):
    torch.save({
        'pi': agent.pi.state_dict(),
        'q1': agent.q1.state_dict(),
        'q2': agent.q2.state_dict(),
        'q1_target': agent.q1_target.state_dict(),
        'q2_target': agent.q2_target.state_dict(),
        'n_epi': n_epi,
        'best_reward': best_reward,
        'obs_mean': agent.obs_mean,
        'obs_var': agent.obs_var,
        'obs_count': agent.obs_count,
    }, SAVE_PATH)


import glob, shutil, os

def sync_videos_to_drive():
    drive_videos = '/content/drive/MyDrive/RL_project_hardcore/videos'
    os.makedirs(drive_videos, exist_ok=True)
    for f in glob.glob('/content/**/*.mp4', recursive=True):
        if '/drive/' not in f:
            dst = os.path.join(drive_videos, os.path.basename(f))
            shutil.copy2(f, dst)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# initialise environment
env = rld.make("rldurham/Walker", render_mode="rgb_array", hardcore=True)
rld.seed_everything(42, env)

env = rld.Recorder(
    env,
    smoothing=10,                       # track rolling averages (useful for plotting)
    video=True,                         # enable recording videos
    video_folder="videos",              # folder for videos
    video_prefix="fyzr56-agent-video",  # prefix for videos (replace xxxx00 with your username)
    logs=True,                          # keep logs
)
recorder = env
recorder.video = False
tracker = rld.InfoTracker()

# clip negative rewards (known trick in Walker environment)
env = rld.transparent_wrapper(gym.wrappers.ClipReward)(env, min_reward=-10)

# initialise agent
agent = Agent(env)
best_reward = -float('inf')

start_epi = 0

for n_epi in range(start_epi, 2101):

    recorder.video = (n_epi + 1) % 10 == 0 and (n_epi + 1) >= 1900
    info = agent.episode()
    tracker.track(info)
    episode_reward = info.get('r', 0)

    if episode_reward > best_reward:
        print(f"[Episode {n_epi}] Best model saved! reward={best_reward:.1f}")

    if (n_epi + 1) % 10 == 0:
        save_checkpoint(agent, n_epi, best_reward)
        tracker.plot(r_mean_=True, r_std_=True, r_sum=dict(linestyle=':', marker='x'))

    if (n_epi + 1) % 25 == 0 and (n_epi + 1) >= 1900:
        #env.write_log(folder="/content/drive/MyDrive/RL_project_hardcore", file="fyzr56-agent-log.txt")

        sync_videos_to_drive()

env.write_log(folder="/content/drive/MyDrive/RL_project_hardcore", file="fyzr56-agent-log.txt")
env.close()
